# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Articles Dataset Exploration

# %%
articles_df = pd.read_csv("data/local_news_articles.csv")

articles_df
# Out:
#      article_id                                                url  \
# 0          4208  https://timesofmalta.com/article/driver-stuck-...
# 1          4167  https://timesofmalta.com/article/pn-slams-gove...
# 2          4093  https://timesofmalta.com/article/motorcyclist-...
# 3          4110  https://timesofmalta.com/article/skip-involved...
# 4          4066  https://timesofmalta.com/article/two-people-in...
# ..          ...                                                ...
# 316      496574  https://timesofmalta.com/article/watch-msida-f...
# 317      496586  https://timesofmalta.com/article/today-front-p...
# 318      496577  https://timesofmalta.com/article/traffic-overt...
# 319      496733  https://timesofmalta.com/article/employer-clea...
# 320      496772  https://timesofmalta.com/article/tourist-acqui...
#
#         source_name                source_url  \
# 0    Times of Malta  https://timesofmalta.com
# 1    Times of Malta  https://timesofmalta.com
# 2    Times of Malta  https://timesofmalta.com
# 3    Times of Malta  https://timesofmalta.com
# 4    Times of Malta  https://timesofmalta.com
# ..              ...                       ...
# 316  Times of Malta  https://timesofmalta.com
# 317  Times of Malta  https://timesofmalta.com
# 318  Times of Malta  https://timesofmalta.com
# 319  Times of Malta  https://timesofmalta.com
# 320  Times of Malta  https://timesofmalta.com
#
#                                                  title  \
# 0    Driver stuck in traffic says speeding LESA car...
# 1    PN slams government for diverting EU bus funds...
# 2    Motorcyclist seriously hurt in St Paul's Bay b...
# 3    Skip involved in horror St Paul’s Bay bypass c...
# 4    Two people, including teenage girl, critically...
# ..                                                 ...
# 316  Watch: Msida flyover to open by end of year as...
# 317                                Today's front pages
# 318  Traffic overtakes cost of living to become peo...
# 319  Employer cleared of responsibility for young w...
# 320  Tourist cleared of injuring man in db Seabank ...
#
#                                               subtitle     author_name  \
# 0    ‘I was shocked at that moment but more so frus...       Emma Borg
# 1    'By encouraging the use of private cars, the g...  Times of Malta
# 2    Residents complained several times about inade...  Times of Malta
# 3    Motorcyclist hurt in crash on Wednesday evenin...       Emma Borg
# 4    Incidents in Mellieħa and Gudja on Friday even...  Times of Malta
# ..                                                 ...             ...
# 316  'The flyover will allow us to create a new ope...    Daniel Ellul
# 317              The top stories in Malta's newspapers  Times of Malta
# 318  Poll data suggests frustration on Maltese road...   Bertrand Borg
# 319  Court raps police, OHSA for not working togeth...   Monique Agius
# 320  Court acquits British tourist who punched man ...   Monique Agius
#
#     publish_date                                            content  \
# 0     2024-12-07  A motorist claims his car mirror was shattered...
# 1     2024-12-09  The PN on Monday slammed the government for di...
# 2     2024-12-11  A motorcyclist was rushed to hospital in a cri...
# 3     2024-12-12  A private contractor who placed a skip on St P...
# 4     2024-12-14  A 29-year-old man and 17-year-old girl were cr...
# ..           ...                                                ...
# 316   2025-10-12  The Msida flyover will open by the end of the ...
# 317   2025-10-13  The following are the top stories in Malta's n...
# 318   2025-10-13  Traffic, parking and public transport-related ...
# 319   2025-10-14  A court has sharply criticised the police and ...
# 320   2025-10-15  A man was acquitted on Wednesday morning in co...
#
#                                          top_image_url  \
# 0    https://cdn-attachments.timesofmalta.com/706da...
# 1    https://cdn-attachments.timesofmalta.com/d9afe...
# 2    https://cdn-attachments.timesofmalta.com/633f6...
# 3    https://cdn-attachments.timesofmalta.com/fc23e...
# 4    https://cdn-attachments.timesofmalta.com/f1761...
# ..                                                 ...
# 316  https://cdn-attachments.timesofmalta.com/f47de...
# 317  https://cdn-attachments.timesofmalta.com/28065...
# 318  https://cdn-attachments.timesofmalta.com/861ca...
# 319  https://cdn-attachments.timesofmalta.com/2d4fb...
# 320  https://cdn-attachments.timesofmalta.com/5847d...
#
#                                      top_image_caption  \
# 0    The broken car mirror. Photo: Frank Xerri De Caro
# 1    PN spokespeople Ryan Callus, Mark Anthony Samm...
# 2                            Photo: Malta Police Force
# 3    A 54-year-old man was seriously injured when h...
# 4    The Ford Fiesta involved in the Gudja collisio...
# ..                                                 ...
# 316  The sixth and final steel piece measures 18 me...
# 317                         File photo: Times of Malta
# 318  Cars in the Santa Venera tunnel. Photo: Chris ...
# 319              The site of the 2015 tragic accident.
# 320  Roderick Sciortino died after the poolside bra...
#
#                         created_at  \
# 0    2025-07-03 15:14:21.554132+00
# 1    2025-07-03 15:14:10.643172+00
# 2    2025-07-03 15:13:50.605708+00
# 3    2025-07-03 15:13:54.812813+00
# 4     2025-07-03 15:13:43.83839+00
# ..                             ...
# 316  2025-10-12 16:57:00.930159+00
# 317  2025-10-13 08:04:55.910209+00
# 318  2025-10-13 05:03:22.837075+00
# 319  2025-10-14 14:01:03.493399+00
# 320  2025-10-15 08:09:43.969247+00
#
#                                                   tags categories
# 0                             {Accident,Lesa,National}         {}
# 1    {"Climate Change",Environment,"European Union"...         {}
# 2          {Accident,National,"St Paul’S Bay",Traffic}         {}
# 3                  {Accident,National,"St Paul’S Bay"}         {}
# 4           {Accident,Gudja,Mellieħa,National,Traffic}         {}
# ..                                                 ...        ...
# 316                           {Msida,National,Traffic}         {}
# 317            {Media,National,"Social Media",Traffic}         {}
# 318                        {National,Politics,Traffic}         {}
# 319             {Accident,Construction,Court,National}         {}
# 320  {Accident,Court,Hotels/Hostels/Airbnb,National...         {}
#
# [321 rows x 14 columns]

# %%
articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   article_id         321 non-null    int64
#  1   url                321 non-null    object
#  2   source_name        321 non-null    object
#  3   source_url         321 non-null    object
#  4   title              321 non-null    object
#  5   subtitle           313 non-null    object
#  6   author_name        321 non-null    object
#  7   publish_date       321 non-null    object
#  8   content            321 non-null    object
#  9   top_image_url      318 non-null    object
#  10  top_image_caption  312 non-null    object
#  11  created_at         321 non-null    object
#  12  tags               321 non-null    object
#  13  categories         321 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 35.2+ KB

# %% [markdown]
# # Police Press Releases Data Exploration

# %%
police_releases_df = pd.read_csv("data/police_press_releases.csv")

police_releases_df
# Out:
#                                                  title date_published  \
# 0    Collision between a car and a motorbike in Żur...     2025-10-09
# 1                      Car-motorcycle traffic accident     2025-06-20
# 2                Car-motorcycle collision in Ħal Qormi     2025-05-12
# 3       Collision between motorcycle and car in Għaxaq     2025-07-30
# 4                             Car-motorcycle collision     2025-04-07
# ..                                                 ...            ...
# 106                      Motorcycle accident in Attard     2025-02-05
# 107                            Naxxar traffic accident     2024-12-19
# 108                          Żebbuġ traffic accident       2025-03-16
# 109              Collision between a car and e-scooter     2025-07-18
# 110                    Traffic accident in Gwardamanġa     2025-08-12
#
#     date_modified                                            content
# 0      2025-10-09  Today, at around 0930hrs, the Police were info...
# 1      2025-06-20  Yesterday, at around 1830hrs, the Police were ...
# 2      2025-05-12  Today, at around 0800hrs, the Police were info...
# 3      2025-07-30  Yesterday, at around 1800hrs, the Police were ...
# 4      2025-04-07  Yesterday, at around quarter to nine in the ev...
# ..            ...                                                ...
# 106    2025-02-05  A 52-year-old man and residing in Ħaż-Żebbuġ, ...
# 107    2024-12-19  Today, at around 1045hrs, the Police were info...
# 108    2025-03-16  Today, at around 0800hrs, the Police were info...
# 109    2025-07-18  Yesterday, at around 2215 hrs, the Police were...
# 110    2025-08-12  Today, at around 0700hrs, the Police were info...
#
# [111 rows x 4 columns]

# %%
police_releases_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           111 non-null    object
#  1   date_published  111 non-null    object
#  2   date_modified   111 non-null    object
#  3   content         111 non-null    object
# dtypes: object(4)
# memory usage: 3.6+ KB

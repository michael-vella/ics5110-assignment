# %% [markdown]
# # Notebook Purpose
#
# The purpose of this notebook is to combine all the feature extraction points into one CSV file so that we can validate all the data extracted programatically via regex or LLMs manually.

# %% [markdown]
# ## Download Packages Required
#
# - Install `pandas` package.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/michael/git-repos/ics5110-assignment/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/michael/git-repos/ics5110-assignment/.venv/lib/python3.12/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/michael/git-repos/ics5110-assignment/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/michael/git-repos/ics5110-assignment/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/michael/git-repos/ics5110-assignment/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/michael/git-repos/ics5110-assignment/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Imports

# %%
import ast
import pandas as pd
from IPython.display import display

# %% [markdown]
# ## Attributes

# %%
data_folder_path = "../../../data"
processed_data_folder_path = f"{data_folder_path}/processed"

local_news_articles_csv = f"{data_folder_path}/local_news_articles.csv"
police_press_releases_csv = f"{data_folder_path}/police_press_releases.csv"
og_prefix = "og_"

regex_dtime_news_articles_csv = f"{processed_data_folder_path}/road_accidents_with_datetime.csv"
regex_dtime_press_releases_csv = f"{processed_data_folder_path}/police_releases_with_datetime.csv"
regex_dtime_prefix = "regxdt_"

llm_news_articles_csv = f"{processed_data_folder_path}/llm_local_news_articles.csv"
llm_press_releases_csv = f"{processed_data_folder_path}/llm_press_releases.csv"
llm_prefix = "llm_"

# to-do: wait for Paul to extract town/street of both CSVs to include in feature exctration

# csv save file paths of combined dataframes
combined_news_articles_csv = f"{processed_data_folder_path}/combined_news_articles.csv"
combined_press_releases_csv = f"{processed_data_folder_path}/combined_press_releases.csv"

# %% [markdown]
# ## Methods

# %%
def parse_llm_drivers(x):
    if pd.isna(x) or x.strip() == "":
        return []
    return ast.literal_eval(x)

# %% [markdown]
# ## Combine all DataFrames into one
#
# Various different attempts have been made to extract features.
#
# - Datetime feature extraction using Regex.
# - Town/Street feature extraction using Reges.
# - General feature extraction using LLM.

# %% [markdown]
# ### Local News Articles
#
# Combination of all dataframes for the local news articles.

# %% [markdown]
# #### Original CSV File
#
# We select only the columns of importance and add `og_` prefix to the column names.
#
# This way, when we join the DataFrames together, we will know from which DataFrame the column comes from.

# %%
articles_df = pd.read_csv(local_news_articles_csv)

articles_df = (
    articles_df[[
        "article_id",
        "url",
        "source_name",
        "source_url",
        "title",
        "subtitle",
        # "author_name", -> not interested in the name of the author
        "publish_date",
        "content",
        "top_image_url",
        "top_image_caption",
        "created_at",
        "tags",
        # "categories" -> always empty set, not interested in this column
    ]]
    .rename(columns={
        "article_id": "article_id",
        "url": f"{og_prefix}url",
        "source_name": f"{og_prefix}source_name",
        "source_url": f"{og_prefix}source_url",
        "title": f"{og_prefix}title",
        "subtitle": f"{og_prefix}subtitle",
        "publish_date": f"{og_prefix}publish_date",
        "content": f"{og_prefix}content",
        "top_image_url": f"{og_prefix}top_image_url",
        "top_image_caption": f"{og_prefix}top_image_caption",
        "created_at": f"{og_prefix}created_at",
        "tags": f"{og_prefix}tags",
    })
)

display(articles_df)
# Out:
#      article_id                                             og_url  \
# 0          4208  https://timesofmalta.com/article/driver-stuck-...
# 1          4167  https://timesofmalta.com/article/pn-slams-gove...
# 2          4093  https://timesofmalta.com/article/motorcyclist-...
# 3          4110  https://timesofmalta.com/article/skip-involved...
# 4          4066  https://timesofmalta.com/article/two-people-in...
# ..          ...                                                ...
# 316      496574  https://timesofmalta.com/article/watch-msida-f...
# 317      496586  https://timesofmalta.com/article/today-front-p...
# 318      496577  https://timesofmalta.com/article/traffic-overt...
# 319      496733  https://timesofmalta.com/article/employer-clea...
# 320      496772  https://timesofmalta.com/article/tourist-acqui...
#
#      og_source_name             og_source_url  \
# 0    Times of Malta  https://timesofmalta.com
# 1    Times of Malta  https://timesofmalta.com
# 2    Times of Malta  https://timesofmalta.com
# 3    Times of Malta  https://timesofmalta.com
# 4    Times of Malta  https://timesofmalta.com
# ..              ...                       ...
# 316  Times of Malta  https://timesofmalta.com
# 317  Times of Malta  https://timesofmalta.com
# 318  Times of Malta  https://timesofmalta.com
# 319  Times of Malta  https://timesofmalta.com
# 320  Times of Malta  https://timesofmalta.com
#
#                                               og_title  \
# 0    Driver stuck in traffic says speeding LESA car...
# 1    PN slams government for diverting EU bus funds...
# 2    Motorcyclist seriously hurt in St Paul's Bay b...
# 3    Skip involved in horror St Paul’s Bay bypass c...
# 4    Two people, including teenage girl, critically...
# ..                                                 ...
# 316  Watch: Msida flyover to open by end of year as...
# 317                                Today's front pages
# 318  Traffic overtakes cost of living to become peo...
# 319  Employer cleared of responsibility for young w...
# 320  Tourist cleared of injuring man in db Seabank ...
#
#                                            og_subtitle og_publish_date  \
# 0    ‘I was shocked at that moment but more so frus...      2024-12-07
# 1    'By encouraging the use of private cars, the g...      2024-12-09
# 2    Residents complained several times about inade...      2024-12-11
# 3    Motorcyclist hurt in crash on Wednesday evenin...      2024-12-12
# 4    Incidents in Mellieħa and Gudja on Friday even...      2024-12-14
# ..                                                 ...             ...
# 316  'The flyover will allow us to create a new ope...      2025-10-12
# 317              The top stories in Malta's newspapers      2025-10-13
# 318  Poll data suggests frustration on Maltese road...      2025-10-13
# 319  Court raps police, OHSA for not working togeth...      2025-10-14
# 320  Court acquits British tourist who punched man ...      2025-10-15
#
#                                             og_content  \
# 0    A motorist claims his car mirror was shattered...
# 1    The PN on Monday slammed the government for di...
# 2    A motorcyclist was rushed to hospital in a cri...
# 3    A private contractor who placed a skip on St P...
# 4    A 29-year-old man and 17-year-old girl were cr...
# ..                                                 ...
# 316  The Msida flyover will open by the end of the ...
# 317  The following are the top stories in Malta's n...
# 318  Traffic, parking and public transport-related ...
# 319  A court has sharply criticised the police and ...
# 320  A man was acquitted on Wednesday morning in co...
#
#                                       og_top_image_url  \
# 0    https://cdn-attachments.timesofmalta.com/706da...
# 1    https://cdn-attachments.timesofmalta.com/d9afe...
# 2    https://cdn-attachments.timesofmalta.com/633f6...
# 3    https://cdn-attachments.timesofmalta.com/fc23e...
# 4    https://cdn-attachments.timesofmalta.com/f1761...
# ..                                                 ...
# 316  https://cdn-attachments.timesofmalta.com/f47de...
# 317  https://cdn-attachments.timesofmalta.com/28065...
# 318  https://cdn-attachments.timesofmalta.com/861ca...
# 319  https://cdn-attachments.timesofmalta.com/2d4fb...
# 320  https://cdn-attachments.timesofmalta.com/5847d...
#
#                                   og_top_image_caption  \
# 0    The broken car mirror. Photo: Frank Xerri De Caro
# 1    PN spokespeople Ryan Callus, Mark Anthony Samm...
# 2                            Photo: Malta Police Force
# 3    A 54-year-old man was seriously injured when h...
# 4    The Ford Fiesta involved in the Gudja collisio...
# ..                                                 ...
# 316  The sixth and final steel piece measures 18 me...
# 317                         File photo: Times of Malta
# 318  Cars in the Santa Venera tunnel. Photo: Chris ...
# 319              The site of the 2015 tragic accident.
# 320  Roderick Sciortino died after the poolside bra...
#
#                      og_created_at  \
# 0    2025-07-03 15:14:21.554132+00
# 1    2025-07-03 15:14:10.643172+00
# 2    2025-07-03 15:13:50.605708+00
# 3    2025-07-03 15:13:54.812813+00
# 4     2025-07-03 15:13:43.83839+00
# ..                             ...
# 316  2025-10-12 16:57:00.930159+00
# 317  2025-10-13 08:04:55.910209+00
# 318  2025-10-13 05:03:22.837075+00
# 319  2025-10-14 14:01:03.493399+00
# 320  2025-10-15 08:09:43.969247+00
#
#                                                og_tags
# 0                             {Accident,Lesa,National}
# 1    {"Climate Change",Environment,"European Union"...
# 2          {Accident,National,"St Paul’S Bay",Traffic}
# 3                  {Accident,National,"St Paul’S Bay"}
# 4           {Accident,Gudja,Mellieħa,National,Traffic}
# ..                                                 ...
# 316                           {Msida,National,Traffic}
# 317            {Media,National,"Social Media",Traffic}
# 318                        {National,Politics,Traffic}
# 319             {Accident,Construction,Court,National}
# 320  {Accident,Court,Hotels/Hostels/Airbnb,National...
#
# [321 rows x 12 columns]

# %% [markdown]
# #### Datetime extraction with regex
#
# We select only the columns of importance and add `regxdt_` prefix to the column names.

# %%
regex_dtime_articles_df = pd.read_csv(regex_dtime_news_articles_csv)

regex_dtime_articles_df = (
    regex_dtime_articles_df[[
        "article_id",
        "accident_datetime",
    ]]
    .rename(columns={
        "article_id": "article_id",
        "accident_datetime": f"{regex_dtime_prefix}accident_datetime",
    })
)

display(regex_dtime_articles_df)
# Out:
#      article_id regxdt_accident_datetime
# 0          4208      2024-12-04 00:00:00
# 1          4167      2024-12-09 00:00:00
# 2          4093      2024-12-11 17:00:00
# 3          4110      2024-12-11 13:00:00
# 4          4066      2024-12-13 17:30:00
# ..          ...                      ...
# 316      496574      2025-10-12 00:00:00
# 317      496586      2025-10-13 00:00:00
# 318      496577      2025-10-13 00:00:00
# 319      496733      2025-10-14 00:00:00
# 320      496772      2025-10-15 00:00:00
#
# [321 rows x 2 columns]

# %% [markdown]
# #### Feature Extraction with LLM
#
# We select only the columns of importance and add `llm_` prefix to the column names.

# %%
llm_articles_df = pd.read_csv(llm_news_articles_csv)

llm_articles_df = (
    llm_articles_df[[
        "id_column", # article_id
        "is_accident",
        "street",
        "city",
        "number_injured",
        "accident_severity",
        "drivers",
    ]]
    .rename(columns={
        "id_column": "article_id",
        "is_accident": f"{llm_prefix}is_accident",
        "street": f"{llm_prefix}street",
        "city": f"{llm_prefix}city",
        "number_injured": f"{llm_prefix}number_injured",
        "accident_severity": f"{llm_prefix}accident_severity",
        "drivers": f"{llm_prefix}drivers",
    })
)

display(llm_articles_df)
# Out:
#      article_id  llm_is_accident            llm_street       llm_city  \
# 0          4208             True         Regional Road    St Julian's
# 1          4167            False                   NaN            NaN
# 2          4093             True  St Paul's Bay bypass  St Paul's Bay
# 3          4110             True  St Paul’s Bay bypass  St Paul's Bay
# 4          4066             True                   NaN            NaN
# ..          ...              ...                   ...            ...
# 313      496574            False                   NaN            NaN
# 314      496586            False                   NaN            NaN
# 315      496577            False                   NaN            NaN
# 316      496733            False                   NaN            NaN
# 317      496772            False                   NaN            NaN
#
#     llm_number_injured llm_accident_severity  \
# 0                    0           No Injuries
# 1                  NaN                   NaN
# 2                    1               Serious
# 3                    1               Serious
# 4                  NaN                   NaN
# ..                 ...                   ...
# 313                NaN                   NaN
# 314                NaN                   NaN
# 315                NaN                   NaN
# 316                NaN                   NaN
# 317                NaN                   NaN
#
#                                            llm_drivers
# 0    [{'vehicle_type': 'Toyota Yaris', 'vehicle_dam...
# 1                                                  NaN
# 2    [{'vehicle_type': 'Motorcycle', 'vehicle_damag...
# 3    [{'vehicle_type': 'Motorcycle', 'vehicle_damag...
# 4                                                  NaN
# ..                                                 ...
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
# 317                                                NaN
#
# [318 rows x 7 columns]

# %% [markdown]
# #### Combined News Articles
#
# Combine news articles DataFrames together.

# %%
joined_articles_df = (
    articles_df
    .merge(regex_dtime_articles_df, on="article_id", how="left")
    .merge(llm_articles_df, on="article_id", how="left")
)

joined_articles_df["llm_drivers"] = joined_articles_df["llm_drivers"].apply(parse_llm_drivers)
exploded_articles_df = joined_articles_df.explode("llm_drivers", ignore_index=True)

combined_articles_df = pd.concat(
    [
        exploded_articles_df.drop(columns=["llm_drivers"]),
        pd.json_normalize(exploded_articles_df["llm_drivers"])
    ],
    axis=1
).rename(columns={
    "vehicle_type": f"{llm_prefix}_vehicle_type",
    "vehicle_damage_severity": f"{llm_prefix}vehicle_damage_severity",
    "driver_age": f"{llm_prefix}driver_age",
    "driver_gender": f"{llm_prefix}driver_gender",
    "is_victim": f"{llm_prefix}is_victim",
})

display(combined_articles_df)

combined_articles_df.to_csv(combined_news_articles_csv)
# Out:
#      article_id                                             og_url  \
# 0          4208  https://timesofmalta.com/article/driver-stuck-...
# 1          4208  https://timesofmalta.com/article/driver-stuck-...
# 2          4167  https://timesofmalta.com/article/pn-slams-gove...
# 3          4093  https://timesofmalta.com/article/motorcyclist-...
# 4          4110  https://timesofmalta.com/article/skip-involved...
# ..          ...                                                ...
# 448      496574  https://timesofmalta.com/article/watch-msida-f...
# 449      496586  https://timesofmalta.com/article/today-front-p...
# 450      496577  https://timesofmalta.com/article/traffic-overt...
# 451      496733  https://timesofmalta.com/article/employer-clea...
# 452      496772  https://timesofmalta.com/article/tourist-acqui...
#
#      og_source_name             og_source_url  \
# 0    Times of Malta  https://timesofmalta.com
# 1    Times of Malta  https://timesofmalta.com
# 2    Times of Malta  https://timesofmalta.com
# 3    Times of Malta  https://timesofmalta.com
# 4    Times of Malta  https://timesofmalta.com
# ..              ...                       ...
# 448  Times of Malta  https://timesofmalta.com
# 449  Times of Malta  https://timesofmalta.com
# 450  Times of Malta  https://timesofmalta.com
# 451  Times of Malta  https://timesofmalta.com
# 452  Times of Malta  https://timesofmalta.com
#
#                                               og_title  \
# 0    Driver stuck in traffic says speeding LESA car...
# 1    Driver stuck in traffic says speeding LESA car...
# 2    PN slams government for diverting EU bus funds...
# 3    Motorcyclist seriously hurt in St Paul's Bay b...
# 4    Skip involved in horror St Paul’s Bay bypass c...
# ..                                                 ...
# 448  Watch: Msida flyover to open by end of year as...
# 449                                Today's front pages
# 450  Traffic overtakes cost of living to become peo...
# 451  Employer cleared of responsibility for young w...
# 452  Tourist cleared of injuring man in db Seabank ...
#
#                                            og_subtitle og_publish_date  \
# 0    ‘I was shocked at that moment but more so frus...      2024-12-07
# 1    ‘I was shocked at that moment but more so frus...      2024-12-07
# 2    'By encouraging the use of private cars, the g...      2024-12-09
# 3    Residents complained several times about inade...      2024-12-11
# 4    Motorcyclist hurt in crash on Wednesday evenin...      2024-12-12
# ..                                                 ...             ...
# 448  'The flyover will allow us to create a new ope...      2025-10-12
# 449              The top stories in Malta's newspapers      2025-10-13
# 450  Poll data suggests frustration on Maltese road...      2025-10-13
# 451  Court raps police, OHSA for not working togeth...      2025-10-14
# 452  Court acquits British tourist who punched man ...      2025-10-15
#
#                                             og_content  \
# 0    A motorist claims his car mirror was shattered...
# 1    A motorist claims his car mirror was shattered...
# 2    The PN on Monday slammed the government for di...
# 3    A motorcyclist was rushed to hospital in a cri...
# 4    A private contractor who placed a skip on St P...
# ..                                                 ...
# 448  The Msida flyover will open by the end of the ...
# 449  The following are the top stories in Malta's n...
# 450  Traffic, parking and public transport-related ...
# 451  A court has sharply criticised the police and ...
# 452  A man was acquitted on Wednesday morning in co...
#
#                                       og_top_image_url  \
# 0    https://cdn-attachments.timesofmalta.com/706da...
# 1    https://cdn-attachments.timesofmalta.com/706da...
# 2    https://cdn-attachments.timesofmalta.com/d9afe...
# 3    https://cdn-attachments.timesofmalta.com/633f6...
# 4    https://cdn-attachments.timesofmalta.com/fc23e...
# ..                                                 ...
# 448  https://cdn-attachments.timesofmalta.com/f47de...
# 449  https://cdn-attachments.timesofmalta.com/28065...
# 450  https://cdn-attachments.timesofmalta.com/861ca...
# 451  https://cdn-attachments.timesofmalta.com/2d4fb...
# 452  https://cdn-attachments.timesofmalta.com/5847d...
#
#                                   og_top_image_caption  ... llm_is_accident  \
# 0    The broken car mirror. Photo: Frank Xerri De Caro  ...            True
# 1    The broken car mirror. Photo: Frank Xerri De Caro  ...            True
# 2    PN spokespeople Ryan Callus, Mark Anthony Samm...  ...           False
# 3                            Photo: Malta Police Force  ...            True
# 4    A 54-year-old man was seriously injured when h...  ...            True
# ..                                                 ...  ...             ...
# 448  The sixth and final steel piece measures 18 me...  ...           False
# 449                         File photo: Times of Malta  ...           False
# 450  Cars in the Santa Venera tunnel. Photo: Chris ...  ...           False
# 451              The site of the 2015 tragic accident.  ...           False
# 452  Roderick Sciortino died after the poolside bra...  ...           False
#
#                llm_street       llm_city llm_number_injured  \
# 0           Regional Road    St Julian's                  0
# 1           Regional Road    St Julian's                  0
# 2                     NaN            NaN                NaN
# 3    St Paul's Bay bypass  St Paul's Bay                  1
# 4    St Paul’s Bay bypass  St Paul's Bay                  1
# ..                    ...            ...                ...
# 448                   NaN            NaN                NaN
# 449                   NaN            NaN                NaN
# 450                   NaN            NaN                NaN
# 451                   NaN            NaN                NaN
# 452                   NaN            NaN                NaN
#
#     llm_accident_severity llm__vehicle_type llm_vehicle_damage_severity  \
# 0             No Injuries      Toyota Yaris                       Minor
# 1             No Injuries      LESA vehicle                   No damage
# 2                     NaN               NaN                         NaN
# 3                 Serious        Motorcycle                       Major
# 4                 Serious        Motorcycle                        none
# ..                    ...               ...                         ...
# 448                   NaN               NaN                         NaN
# 449                   NaN               NaN                         NaN
# 450                   NaN               NaN                         NaN
# 451                   NaN               NaN                         NaN
# 452                   NaN               NaN                         NaN
#
#     llm_driver_age llm_driver_gender llm_is_victim
# 0               78                 M          True
# 1             none              none         False
# 2              NaN               NaN           NaN
# 3               54                 M          True
# 4               54                 M          True
# ..             ...               ...           ...
# 448            NaN               NaN           NaN
# 449            NaN               NaN           NaN
# 450            NaN               NaN           NaN
# 451            NaN               NaN           NaN
# 452            NaN               NaN           NaN
#
# [453 rows x 23 columns]

# %% [markdown]
# ### Police Press Releases
#
# Combination of all dataframes for the police press releases.

# %% [markdown]
# #### Original CSV File

# %%
police_releases_df = pd.read_csv(police_press_releases_csv)
police_releases_df.insert(0, 'release_id', range(1, len(police_releases_df) + 1)) # use similar pre-processing used by Isaac to generate surrogate key

police_releases_df = (
    police_releases_df[[
        "release_id",
        "title",
        "content",
        "date_published",
        "date_modified",
    ]]
    .rename(columns={
        "release_id": "release_id",
        "title": f"{og_prefix}title",
        "content": f"{og_prefix}content",
        "date_published": f"{og_prefix}date_published",
        "date_modified": f"{og_prefix}date_modified",
    })
)

display(police_releases_df)
# Out:
#      release_id                                           og_title  \
# 0             1  Collision between a car and a motorbike in Żur...
# 1             2                    Car-motorcycle traffic accident
# 2             3              Car-motorcycle collision in Ħal Qormi
# 3             4     Collision between motorcycle and car in Għaxaq
# 4             5                           Car-motorcycle collision
# ..          ...                                                ...
# 106         107                      Motorcycle accident in Attard
# 107         108                            Naxxar traffic accident
# 108         109                          Żebbuġ traffic accident
# 109         110              Collision between a car and e-scooter
# 110         111                    Traffic accident in Gwardamanġa
#
#                                             og_content og_date_published  \
# 0    Today, at around 0930hrs, the Police were info...        2025-10-09
# 1    Yesterday, at around 1830hrs, the Police were ...        2025-06-20
# 2    Today, at around 0800hrs, the Police were info...        2025-05-12
# 3    Yesterday, at around 1800hrs, the Police were ...        2025-07-30
# 4    Yesterday, at around quarter to nine in the ev...        2025-04-07
# ..                                                 ...               ...
# 106  A 52-year-old man and residing in Ħaż-Żebbuġ, ...        2025-02-05
# 107  Today, at around 1045hrs, the Police were info...        2024-12-19
# 108  Today, at around 0800hrs, the Police were info...        2025-03-16
# 109  Yesterday, at around 2215 hrs, the Police were...        2025-07-18
# 110  Today, at around 0700hrs, the Police were info...        2025-08-12
#
#     og_date_modified
# 0         2025-10-09
# 1         2025-06-20
# 2         2025-05-12
# 3         2025-07-30
# 4         2025-04-07
# ..               ...
# 106       2025-02-05
# 107       2024-12-19
# 108       2025-03-16
# 109       2025-07-18
# 110       2025-08-12
#
# [111 rows x 5 columns]

# %% [markdown]
# #### Datetime extraction with regex

# %%
regex_dtime_police_releases_df = pd.read_csv(regex_dtime_press_releases_csv)

regex_dtime_police_releases_df = (
    regex_dtime_police_releases_df[[
        "release_id",
        "accident_datetime",
    ]]
    .rename(columns={
        "release_id": "release_id",
        "accident_datetime": f"{regex_dtime_prefix}accident_datetime",
    })
)

display(regex_dtime_police_releases_df)
# Out:
#      release_id regxdt_accident_datetime
# 0             1          09/10/2025 9:30
# 1             2         19/06/2025 18:30
# 2             3          12/05/2025 8:00
# 3             4         29/07/2025 18:00
# 4             5         06/04/2025 20:45
# ..          ...                      ...
# 106         107          05/02/2025 9:00
# 107         108         19/12/2024 10:45
# 108         109          16/03/2025 8:00
# 109         110         17/07/2025 22:15
# 110         111          12/08/2025 7:00
#
# [111 rows x 2 columns]

# %% [markdown]
# #### Feature Extraction with LLM

# %%
llm_police_releases_df = pd.read_csv(llm_press_releases_csv)

llm_police_releases_df = (
    llm_police_releases_df[[
        "id_column", # release_id
        "is_accident",
        "street",
        "city",
        "number_injured",
        "accident_severity",
        "drivers",
    ]]
    .rename(columns={
        "id_column": "release_id",
        "is_accident": f"{llm_prefix}is_accident",
        "street": f"{llm_prefix}street",
        "city": f"{llm_prefix}city",
        "number_injured": f"{llm_prefix}number_injured",
        "accident_severity": f"{llm_prefix}accident_severity",
        "drivers": f"{llm_prefix}drivers",
    })
)

display(llm_police_releases_df)
# Out:
#      release_id  llm_is_accident                   llm_street     llm_city  \
# 0             1             True        Triq il-Belt Valletta      Żurrieq
# 1             2             True         Triq Dawret il-Gudja        Gudja
# 2             3             True                  Valley Road        Qormi
# 3             4             True       Triq Dawret Ħal Għaxaq       Għaxaq
# 4             5             True               Triq il-Buqana        Rabat
# ..          ...              ...                          ...          ...
# 106         107             True   Vjal L-Istadium Nazzjonali       Attard
# 107         108             True             Triq il-Ġermanja       Naxxar
# 108         109             True              Vjal il-Helsien       Zebbug
# 109         110             True  Triq il-Wied ta’ Birkirkara   Birkirkara
# 110         111             True             St Luke’s Square  Gwardamanġa
#
#      llm_number_injured llm_accident_severity  \
# 0                   1.0               Serious
# 1                   1.0               Serious
# 2                   1.0               Serious
# 3                   1.0               Serious
# 4                   1.0               Serious
# ..                  ...                   ...
# 106                 1.0               Serious
# 107                 1.0               Serious
# 108                 2.0               Serious
# 109                 1.0               Serious
# 110                 2.0               Serious
#
#                                            llm_drivers
# 0    [{'vehicle_type': 'Car', 'vehicle_damage_sever...
# 1    [{'vehicle_type': 'Honda fit', 'vehicle_damage...
# 2    [{'vehicle_type': 'Ford Transit', 'vehicle_dam...
# 3    [{'vehicle_type': 'Volvo XC60', 'vehicle_damag...
# 4    [{'vehicle_type': 'Car', 'vehicle_damage_sever...
# ..                                                 ...
# 106  [{'vehicle_type': 'Motorcycle', 'vehicle_damag...
# 107  [{'vehicle_type': 'Toyota Vitz', 'vehicle_dama...
# 108  [{'vehicle_type': 'Peugeot 306', 'vehicle_dama...
# 109  [{'vehicle_type': 'Car', 'vehicle_damage_sever...
# 110  [{'vehicle_type': 'Volkswagen Caddy', 'vehicle...
#
# [111 rows x 7 columns]

# %% [markdown]
# #### Combined Police Press Releases

# %%
joined_police_releases_df = (
    police_releases_df
    .merge(regex_dtime_police_releases_df, on="release_id", how="left")
    .merge(llm_police_releases_df, on="release_id", how="left")
)

joined_police_releases_df["llm_drivers"] = joined_police_releases_df["llm_drivers"].apply(parse_llm_drivers)
exploded_police_released_df = joined_police_releases_df.explode("llm_drivers", ignore_index=True)

combined_police_releases_df = pd.concat(
    [
        exploded_police_released_df.drop(columns=["llm_drivers"]),
        pd.json_normalize(exploded_police_released_df["llm_drivers"])
    ],
    axis=1
).rename(columns={
    "vehicle_type": f"{llm_prefix}_vehicle_type",
    "vehicle_damage_severity": f"{llm_prefix}vehicle_damage_severity",
    "driver_age": f"{llm_prefix}driver_age",
    "driver_gender": f"{llm_prefix}driver_gender",
    "is_victim": f"{llm_prefix}is_victim",
})

display(combined_police_releases_df)

combined_police_releases_df.to_csv(combined_press_releases_csv)
# Out:
#      release_id                                           og_title  \
# 0             1  Collision between a car and a motorbike in Żur...
# 1             1  Collision between a car and a motorbike in Żur...
# 2             2                    Car-motorcycle traffic accident
# 3             2                    Car-motorcycle traffic accident
# 4             3              Car-motorcycle collision in Ħal Qormi
# ..          ...                                                ...
# 170         109                          Żebbuġ traffic accident
# 171         110              Collision between a car and e-scooter
# 172         110              Collision between a car and e-scooter
# 173         111                    Traffic accident in Gwardamanġa
# 174         111                    Traffic accident in Gwardamanġa
#
#                                             og_content og_date_published  \
# 0    Today, at around 0930hrs, the Police were info...        2025-10-09
# 1    Today, at around 0930hrs, the Police were info...        2025-10-09
# 2    Yesterday, at around 1830hrs, the Police were ...        2025-06-20
# 3    Yesterday, at around 1830hrs, the Police were ...        2025-06-20
# 4    Today, at around 0800hrs, the Police were info...        2025-05-12
# ..                                                 ...               ...
# 170  Today, at around 0800hrs, the Police were info...        2025-03-16
# 171  Yesterday, at around 2215 hrs, the Police were...        2025-07-18
# 172  Yesterday, at around 2215 hrs, the Police were...        2025-07-18
# 173  Today, at around 0700hrs, the Police were info...        2025-08-12
# 174  Today, at around 0700hrs, the Police were info...        2025-08-12
#
#     og_date_modified regxdt_accident_datetime  llm_is_accident  \
# 0         2025-10-09          09/10/2025 9:30             True
# 1         2025-10-09          09/10/2025 9:30             True
# 2         2025-06-20         19/06/2025 18:30             True
# 3         2025-06-20         19/06/2025 18:30             True
# 4         2025-05-12          12/05/2025 8:00             True
# ..               ...                      ...              ...
# 170       2025-03-16          16/03/2025 8:00             True
# 171       2025-07-18         17/07/2025 22:15             True
# 172       2025-07-18         17/07/2025 22:15             True
# 173       2025-08-12          12/08/2025 7:00             True
# 174       2025-08-12          12/08/2025 7:00             True
#
#                       llm_street     llm_city  llm_number_injured  \
# 0          Triq il-Belt Valletta      Żurrieq                 1.0
# 1          Triq il-Belt Valletta      Żurrieq                 1.0
# 2           Triq Dawret il-Gudja        Gudja                 1.0
# 3           Triq Dawret il-Gudja        Gudja                 1.0
# 4                    Valley Road        Qormi                 1.0
# ..                           ...          ...                 ...
# 170              Vjal il-Helsien       Zebbug                 2.0
# 171  Triq il-Wied ta’ Birkirkara   Birkirkara                 1.0
# 172  Triq il-Wied ta’ Birkirkara   Birkirkara                 1.0
# 173             St Luke’s Square  Gwardamanġa                 2.0
# 174             St Luke’s Square  Gwardamanġa                 2.0
#
#     llm_accident_severity          llm__vehicle_type  \
# 0                 Serious                        Car
# 1                 Serious                  Motorbike
# 2                 Serious                  Honda fit
# 3                 Serious  Kawasaki Ninja motorcycle
# 4                 Serious               Ford Transit
# ..                    ...                        ...
# 170               Serious                Peugeot 306
# 171               Serious                        Car
# 172               Serious                  E-scooter
# 173               Serious           Volkswagen Caddy
# 174               Serious         Mercedes Benz E320
#
#     llm_vehicle_damage_severity llm_driver_age llm_driver_gender llm_is_victim
# 0                          none             67                 F         False
# 1                          none             61                 M          True
# 2                          none             64                 M         False
# 3                          none             23                 M          True
# 4                          none             34                 M         False
# ..                          ...            ...               ...           ...
# 170                        none             59                 M         False
# 171                        none             41              none         False
# 172                        none             17              none          True
# 173                        none             62                 M          True
# 174                        none           none              none         False
#
# [175 rows x 16 columns]
